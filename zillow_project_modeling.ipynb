# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
import pandas as pd
from scipy import stats
from pydataset import data
import numpy as np
import env
import matplotlib.pyplot as plt
import os
import prepare
import acquire
import seaborn as sns
import explore
from math import sqrt

# %%
df = acquire.get_zillow_sfr_data()

# %%
train, val, test = prepare.clean_prep_zillow(df)

# %%
x_train, y_train, x_val, y_val, x_test, y_test = prepare.modeling_split(train, val, test, 'tax_value')

# %%
x_train_scaled = prepare.dummy_scale(x_train, x_train)
x_val_scaled = prepare.dummy_scale(x_val, x_train)
x_test_scaled = prepare.dummy_scale(x_test, x_train)

# %%
x_val_scaled.head().T
# Out:
#                 128414    1329078   2023708   362743    585273
# bedroom_1.0    0.000000  0.000000  0.000000  0.000000  0.000000
# bedroom_2.0    0.000000  0.000000  0.000000  0.000000  0.000000
# bedroom_3.0    1.000000  1.000000  0.000000  1.000000  1.000000
# bedroom_4.0    0.000000  0.000000  1.000000  0.000000  0.000000
# bedroom_5.0    0.000000  0.000000  0.000000  0.000000  0.000000
# bedroom_6.0    0.000000  0.000000  0.000000  0.000000  0.000000
# bedroom_7.0    0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_0.5   0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_1.0   0.000000  1.000000  0.000000  0.000000  0.000000
# bathroom_1.5   0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_1.75  0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_2.0   0.000000  0.000000  0.000000  1.000000  0.000000
# bathroom_2.5   1.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_3.0   0.000000  0.000000  1.000000  0.000000  1.000000
# bathroom_3.5   0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_4.0   0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_4.5   0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_5.0   0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_5.5   0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_6.0   0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_6.5   0.000000  0.000000  0.000000  0.000000  0.000000
# bathroom_7.0   0.000000  0.000000  0.000000  0.000000  0.000000
# fips_6059.0    1.000000  0.000000  0.000000  1.000000  0.000000
# fips_6111.0    0.000000  0.000000  0.000000  0.000000  0.000000
# year_bin_b     0.000000  0.000000  0.000000  0.000000  0.000000
# year_bin_c     0.000000  1.000000  0.000000  0.000000  0.000000
# year_bin_d     0.000000  0.000000  0.000000  0.000000  0.000000
# year_bin_e     0.000000  0.000000  0.000000  0.000000  0.000000
# year_bin_f     0.000000  0.000000  0.000000  1.000000  0.000000
# year_bin_g     0.000000  0.000000  0.000000  0.000000  0.000000
# year_bin_h     1.000000  0.000000  0.000000  0.000000  0.000000
# year_bin_i     0.000000  0.000000  0.000000  0.000000  0.000000
# year_bin_j     0.000000  0.000000  1.000000  0.000000  0.000000
# sqft_scaled    0.247112  0.125503  0.344062  0.277352  0.305127
